# %% [markdown]
# # Tasks

# %%
import pandas as pd  # explain keywords are highlighted in green, other strings in red, etc.
import numpy as np

# %% [markdown]
# ## Read the three files into python as dataframes

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %% [markdown]
# ## Standardize header names, Rearrange the columns in the dataframe as needed

# %%
file1 = file1.reindex(sorted(file1.columns), axis=1)

# %%
file2 = file2.reindex(sorted(file2.columns), axis=1)

# %%
file3 = file3.reindex(sorted(file3.columns), axis=1)

# %%
column_titles = []
for i in range(len(file1.columns)):
    column_titles.append(file1.columns[i].lower())
file1.columns = column_titles
file2.columns = column_titles
file3.columns = column_titles

# %%
file3.head()
# Out:
#   customer  customer lifetime value             education gender  income  \
# 0  SA25987              3479.137523  High School or Below      M       0
# 1  TB86706              2502.637401                Master      M       0
# 2  ZL73902              3265.156348              Bachelor      F   25820
# 3  KX23516              4455.843406  High School or Below      F       0
# 4  FN77294              7704.958480  High School or Below      M   30366
#
#    monthly premium auto  number of open complaints    policy type          st  \
# 0                   104                          0  Personal Auto  Washington
# 1                    66                          0  Personal Auto     Arizona
# 2                    82                          0  Personal Auto      Nevada
# 3                   121                          0  Personal Auto  California
# 4                   101                          2  Personal Auto  California
#
#    total claim amount  vehicle class
# ...

# %% [markdown]
# ## Concatenate the three dataframes

# %%
Customer_Analysis_Round_1 = pd.concat([file1, file2, file3], axis=0)
Customer_Analysis_Round_1.shape
# Out:
# (12074, 11)

# %%
y = file2.shape
z = file3.shape
x = file1.shape
x, z, y
# Out:
# ((4008, 11), (7070, 11), (996, 11))

# %%
Customer_Analysis_Round_1.head(10)
# Out:
#   customer customer lifetime value             education gender   income  \
# 0  RB50392                     NaN                Master    NaN      0.0
# 1  QZ44356              697953.59%              Bachelor      F      0.0
# 2  AI49188             1288743.17%              Bachelor      F  48767.0
# 3  WW63253              764586.18%              Bachelor      M      0.0
# 4  GA49547              536307.65%  High School or Below      M  36357.0
# 5  OC83172              825629.78%              Bachelor      F  62902.0
# 6  XZ87318              538089.86%               College      F  55350.0
# 7  CF85061              721610.03%                Master      M      0.0
# 8  DY87989             2412750.40%              Bachelor      M  14072.0
# 9  BQ94931              738817.81%               College      F  28812.0
#
#    monthly premium auto number of open complaints     policy type          st  \
# 0                1000.0                    1/0/00   Personal Auto  Washington
# ...

# %% [markdown]
# ## Which columns are numerical?

# %%
numericals =  Customer_Analysis_Round_1.select_dtypes(include=[np.number])
numericals
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %% [markdown]
# ##Which columns are categorical?

# %%
categoricals =  Customer_Analysis_Round_1.select_dtypes(include=[np.object])
categoricals
# Out:
#      customer customer lifetime value             education gender  \
# 0     RB50392                     NaN                Master    NaN
# 1     QZ44356              697953.59%              Bachelor      F
# 2     AI49188             1288743.17%              Bachelor      F
# 3     WW63253              764586.18%              Bachelor      M
# 4     GA49547              536307.65%  High School or Below      M
# ...       ...                     ...                   ...    ...
# 7065  LA72316                   23406              Bachelor      M
# 7066  PK87824                 3096.51               College      F
# 7067  TD14365                 8163.89              Bachelor      M
# 7068  UP19263                 7524.44               College      M
# 7069  Y167826                 2611.84               College      M
#
#      number of open complaints     policy type          st  vehicle class
# 0                       1/0/00   Personal Auto  Washington  Four-Door Car
# ...

# %% [markdown]
# ## Understand the meaning of all columns

# %%
Customer_Analysis_Round_1.info
# Out:
# <bound method DataFrame.info of      customer customer lifetime value             education gender   income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 7065  LA72316                   23406              Bachelor      M  71941.0
# 7066  PK87824                 3096.51               College      F  21604.0
# 7067  TD14365                 8163.89              Bachelor      M      0.0
# 7068  UP19263                 7524.44               College      M  21941.0
# 7069  Y167826                 2611.84               College      M      0.0
#
# ...

# %%
Customer_Analysis_Round_1.head()
# Out:
#   customer customer lifetime value             education gender   income  \
# 0  RB50392                     NaN                Master    NaN      0.0
# 1  QZ44356              697953.59%              Bachelor      F      0.0
# 2  AI49188             1288743.17%              Bachelor      F  48767.0
# 3  WW63253              764586.18%              Bachelor      M      0.0
# 4  GA49547              536307.65%  High School or Below      M  36357.0
#
#    monthly premium auto number of open complaints     policy type          st  \
# 0                1000.0                    1/0/00   Personal Auto  Washington
# 1                  94.0                    1/0/00   Personal Auto     Arizona
# 2                 108.0                    1/0/00   Personal Auto      Nevada
# 3                 106.0                    1/0/00  Corporate Auto  California
# 4                  68.0                    1/0/00   Personal Auto  Washington
#
#    total claim amount  vehicle class
# ...

# %%
Customer_Analysis_Round_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   customer lifetime value    9130 non-null   object
#  2   education                  9137 non-null   object
#  3   gender                     9015 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   st                         9137 non-null   object
#  9   total claim amount         9137 non-null   float64
#  10  vehicle class              9137 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# # Perform the data cleaning operations mentioned so far in class

# %% [markdown]
# ## Delete the column education and the number of open complaints from the dataframe.

# %%
Customer_Analysis_Round_1.drop(['education', 'number of open complaints'], axis=1, inplace = True)

# %% [markdown]
# ## Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
# Customer_Analysis_Round_1['customer lifetime value'].astype('float64').dtypes

# %%
Customer_Analysis_Round_1['customer lifetime value'] = Customer_Analysis_Round_1['customer lifetime value'].str.rstrip('%').astype('float') / 100.0

# %%
# # Customer_Analysis_Round_1['customer lifetime value']  = Customer_Analysis_Round_1['customer lifetime value'].astype(str).str.replace('%', '')
# Customer_Analysis_Round_1['customer lifetime value']

# %%
# Customer_Analysis_Round_1['customer lifetime value']  = pd.to_numeric(Customer_Analysis_Round_1['customer lifetime value'])

# %%
Customer_Analysis_Round_1['customer lifetime value']
# Out:
# 0              NaN
# 1        6979.5359
# 2       12887.4317
# 3        7645.8618
# 4        5363.0765
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer lifetime value, Length: 12074, dtype: float64

# %% [markdown]
# ## Check for duplicate rows in the data and remove if any.

# %%
Customer_Analysis_Round_1 = Customer_Analysis_Round_1.drop_duplicates()

# %% [markdown]
# ## Filter out the data for customers who have an income of 0 or less.

# %%
Customer_Analysis_Round_1[Customer_Analysis_Round_1['income']>0]
# Out:
#      customer  customer lifetime value gender   income  monthly premium auto  \
# 2     AI49188               12887.4317      F  48767.0                 108.0
# 4     GA49547                5363.0765      M  36357.0                  68.0
# 5     OC83172                8256.2978      F  62902.0                  69.0
# 6     XZ87318                5380.8986      F  55350.0                  67.0
# 8     DY87989               24127.5040      M  14072.0                  71.0
# ...       ...                      ...    ...      ...                   ...
# 7063  TF56202                      NaN      M  66367.0                  64.0
# 7064  YM19146                      NaN      F  47761.0                 104.0
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
#
# ...

# %% [markdown]
# ## Save DataFrame to CSV File

# %%
# Customer_Analysis_Round_1.to_csv('cleaned_data.csv', index=False)
